# %%
import numpy as np
import os

# %%
def fast_bigram(filename):
    p = np.zeros((256,256))
    
    file = open(filename,'rb')
    data = file.read()
    
    print("Generate bigram for " + filename)
    
    for i in range(len(data)-1):
        wn = data[i+1]
        wnm1 = data[i]
        p[wn][wnm1] = p[wn][wnm1] + 1 #Increment count
        
    return p

# %%
categories = ['gif','pe64','mp3','flac','dll','html','pdf','png','xml']

data_dir = '.'

dataset = []

#Generate the dataset.
for category in categories:
    path = os.path.join(data_dir, category)
    class_label = categories.index(category) #Generate class label

    for file in os.listdir(path):
        try:
            file_bigram = fast_bigram(os.path.join(path, file))
            dataset.append([file_bigram, class_label])
        except Exception as e:
            pass

np.save("dataset",dataset)
# Out:
# Generate bigram for ./dll/iesysprep.dll
# Generate bigram for ./dll/fdProxy.dll
# Generate bigram for ./dll/imagehlp.dll
# Generate bigram for ./dll/Family.Client.dll
# Generate bigram for ./dll/fdWCN.dll
# Generate bigram for ./dll/Family.Cache.dll
# Generate bigram for ./dll/feclient.dll
# Generate bigram for ./dll/f3ahvoas.dll
# Generate bigram for ./dll/ExSMime.dll
# Generate bigram for ./dll/Faultrep.dll
# Generate bigram for ./dll/iepeers.dll
# Generate bigram for ./dll/IHDS.dll
# Generate bigram for ./dll/fdBthProxy.dll
# Generate bigram for ./dll/icuin.dll
# Generate bigram for ./dll/fhcat.dll
# Generate bigram for ./dll/fde.dll
# Generate bigram for ./dll/ieframe.dll
# Generate bigram for ./dll/IEAdvpack.dll
# Generate bigram for ./dll/FDResPub.dll
# Generate bigram for ./dll/iesetup.dll
# Generate bigram for ./dll/fdSSDP.dll
# Generate bigram for ./dll/ffbroker.dll
# Generate bigram for ./dll/ExplorerFrame.dll
# Generate bigram for ./dll/FamilySafetyExt.dll
# Generate bigram for ./dll/ieui.dll
# Generate bigram for ./dll/fdBth.dll
# Generate bigram for ./dll/iemigplugin.dll
# Generate bigram for ./dll/fhcpl.dll
# Generate bigram for ./dll/icuuc.dll
# Generate bigram for ./dll/fdeploy.dll
# Generate bigram for ./dll/ihvrilproxy.dll
# Generate bigram for ./dll/IDStore.dll
# Generate bigram for ./dll/fhcfg.dll
# Generate bigram for ./dll/IdListen.dll
# Generate bigram for ./dll/ieapfltr.dll
# Generate bigram for ./dll/iedkcs32.dll
# Generate bigram for ./dll/eventcls.dll
# Generate bigram for ./dll/Family.Authentication.dll
# Generate bigram for ./dll/ifmon.dll
# Generate bigram for ./dll/fhcleanup.dll
# Generate bigram for ./dll/fdPHost.dll
# Generate bigram for ./dll/fdPnp.dll
# Generate bigram for ./dll/fdWNet.dll
# Generate bigram for ./dll/execmodelproxy.dll
# Generate bigram for ./dll/IdCtrls.dll
# Generate bigram for ./dll/fcon.dll
# Generate bigram for ./dll/ifsutilx.dll
# Generate bigram for ./dll/ExecModelClient.dll
# Generate bigram for ./dll/Family.SyncEngine.dll
# Generate bigram for ./dll/ExtrasXmlParser.dll
# Generate bigram for ./dll/ieproxy.dll
# Generate bigram for ./dll/iernonce.dll
# Generate bigram for ./dll/FdDevQuery.dll
# Generate bigram for ./dll/FaxPrinterInstaller.dll
# Generate bigram for ./dll/IKEEXT.DLL
# Generate bigram for ./dll/facecredentialprovider.dll
# Generate bigram for ./dll/iertutil.dll
# Generate bigram for ./dll/igdDiag.dll
# Generate bigram for ./dll/fdprint.dll
# Generate bigram for ./dll/evr.dll
# Generate bigram for ./dll/ifsutil.dll
# Generate bigram for ./dll/fdWSD.dll
# Generate bigram for ./dll/idndl.dll
# Generate bigram for ./pe64/print.exe
# Generate bigram for ./pe64/PackagedCWALauncher.exe
# Generate bigram for ./pe64/provtool.exe
# Generate bigram for ./pe64/qappsrv.exe
# Generate bigram for ./pe64/RemotePosWorker.exe
# Generate bigram for ./pe64/rekeywiz.exe
# Generate bigram for ./pe64/PATHPING.EXE
# Generate bigram for ./pe64/RdpSaUacHelper.exe
# Generate bigram for ./pe64/ReAgentc.exe
# Generate bigram for ./pe64/reg.exe
# Generate bigram for ./pe64/RelPost.exe
# Generate bigram for ./pe64/Register-CimProvider.exe
# Generate bigram for ./pe64/regsvr32.exe
# Generate bigram for ./pe64/relog.exe
# Generate bigram for ./pe64/rasdial.exe
# Generate bigram for ./pe64/ProximityUxHost.exe
# Generate bigram for ./pe64/PinEnrollmentBroker.exe
# Generate bigram for ./pe64/PickerHost.exe
# Generate bigram for ./pe64/RDSPnf.exe
# Generate bigram for ./pe64/rdrleakdiag.exe
# Generate bigram for ./pe64/ResetEngine.exe
# Generate bigram for ./pe64/provlaunch.exe
# Generate bigram for ./pe64/RdpSaProxy.exe
# Generate bigram for ./pe64/refsutil.exe
# Generate bigram for ./pe64/quickassist.exe
# Generate bigram for ./pe64/prevhost.exe
# Generate bigram for ./pe64/PnPUnattend.exe
# Generate bigram for ./pe64/psr.exe
# Generate bigram for ./pe64/pwlauncher.exe
# Generate bigram for ./pe64/PrintIsolationHost.exe
# Generate bigram for ./pe64/RecoveryDrive.exe
# Generate bigram for ./pe64/powercfg.exe
# Generate bigram for ./pe64/resmon.exe
# Generate bigram for ./pe64/printui.exe
# Generate bigram for ./pe64/proquota.exe
# Generate bigram for ./pe64/rdpshell.exe
# Generate bigram for ./pe64/PackageInspector.exe
# Generate bigram for ./pe64/rdpclip.exe
# Generate bigram for ./pe64/prproc.exe
# Generate bigram for ./pe64/PING.EXE
# Generate bigram for ./pe64/poqexec.exe
# Generate bigram for ./pe64/qwinsta.exe
# Generate bigram for ./pe64/rdpsign.exe
# Generate bigram for ./pe64/rdpinit.exe
# Generate bigram for ./pe64/replace.exe
# Generate bigram for ./pe64/RDVGHelper.exe
# Generate bigram for ./pe64/phoneactivate.exe
# Generate bigram for ./pe64/PrintBrmUi.exe
# Generate bigram for ./pe64/recover.exe
# Generate bigram for ./pe64/RMActivate.exe
# Generate bigram for ./pe64/reset.exe
# Generate bigram for ./pe64/pwNative.exe
# Generate bigram for ./pe64/qprocess.exe
# Generate bigram for ./pe64/rasphone.exe
# Generate bigram for ./pe64/regedt32.exe
# Generate bigram for ./pe64/pwcreator.exe
# Generate bigram for ./pe64/regini.exe
# Generate bigram for ./pe64/quser.exe
# Generate bigram for ./pe64/PkgMgr.exe
# Generate bigram for ./pe64/RMActivate_isv.exe
# Generate bigram for ./pe64/pcwrun.exe
# Generate bigram for ./pe64/printfilterpipelinesvc.exe
# Generate bigram for ./pe64/perfmon.exe
# Generate bigram for ./pe64/PresentationHost.exe
# Generate bigram for ./pe64/pnputil.exe
# Generate bigram for ./pe64/PerceptionSimulationDevice.exe
# Generate bigram for ./pe64/rasautou.exe
# Generate bigram for ./pe64/repair-bde.exe
# Generate bigram for ./pe64/RemoteAppLifetimeManager.exe
# Generate bigram for ./pe64/plasrv.exe
# Generate bigram for ./pe64/recdisc.exe
# Generate bigram for ./pe64/PresentationSettings.exe
# Generate bigram for ./pe64/pacjsworker.exe
# Generate bigram for ./pe64/raserver.exe
# Generate bigram for ./pe64/RdpSa.exe
# Generate bigram for ./pe64/PsExec.exe
# Generate bigram for ./pe64/PktMon.exe
# Generate bigram for ./pe64/query.exe
# Generate bigram for ./pe64/pcaui.exe
# Generate bigram for ./pe64/PasswordOnWakeSettingFlyout.exe
# Generate bigram for ./pe64/rdpinput.exe
# Generate bigram for ./pe64/pcalua.exe
